# %%
from imp import reload
from utils import utils
from glob import glob
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import re
reload(utils)
from matplotlib import pyplot as plt

# %%
# 统计训练集 txt 的数量
# 统计测试集 txt 的数量
print('train txt file:{}'.format(len(glob('../data/train_data/*.txt'))))
print('test txt file:{}'.format(len(glob('../data/test_data/*.txt'))))
# Out:
# train txt file:2515
# test txt file:3956

# %%
# 对标签进行分析
label_lst = glob('../data/train_label/*.csv')
label_total = []
for i in tqdm(label_lst):
    label_total.append(pd.read_csv(i).values)
label_total = np.concatenate(label_total,axis=0)
label_total = pd.DataFrame(label_total,columns= ['ID','Category','Pos_b','Pos_e','Privacy'])
# Out:
# 100%|██████████| 2515/2515 [00:07<00:00, 330.39it/s]

# %%
# 查看标签种类
print(np.unique(label_total.Category))
# Out:
# ['QQ' 'address' 'book' 'company' 'email' 'game' 'government' 'mobile'
#  'movie' 'name' 'organization' 'position' 'scene' 'vx']

# %%
# 查看标签分布
pd.value_counts(label_total.Category)
# Out:
# position        3580
# name            3422
# organization    2329
# company         2150
# address         2056
# movie           1901
# game            1571
# government      1187
# scene            990
# book             734
# mobile           277
# email            259
# QQ                28
# vx                19
# Name: Category, dtype: int64

# %%
# 查看是否每个 train data 的 txt 都是没换行符号
tdata_lst = glob('../data/train_data/*.txt')

# %%
for td in tdata_lst:
    if len(utils.read_txt(td))!=1:
        print(td)

# %% [markdown]
# - `../data/train_data/2162.txt`
# - `../data/train_data/1907.txt`
# - `../data/train_data/488.txt`
# - `../data/train_data/2048.txt`
# - `../data/train_data/747.txt`
# - `../data/train_data/1571.txt`
# - `../data/train_data/1501.txt`

# %%
# 查看每个 train data 的 txt 中的长度
len_lst = []
for td in tdata_lst:
    len_lst.append(len(utils.read_txt(td)[0]))
plt.hist(len_lst,bins=20)
# Out:
# (array([4.570e+02, 1.025e+03, 3.900e+02, 1.970e+02, 1.410e+02, 8.700e+01,
#         7.400e+01, 4.200e+01, 2.800e+01, 2.300e+01, 2.100e+01, 9.000e+00,
#         9.000e+00, 4.000e+00, 0.000e+00, 2.000e+00, 2.000e+00, 3.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  6. ,  54.4, 102.8, 151.2, 199.6, 248. , 296.4, 344.8, 393.2,
#         441.6, 490. , 538.4, 586.8, 635.2, 683.6, 732. , 780.4, 828.8,
#         877.2, 925.6, 974. ]),
#  <a list of 20 Patch objects>)

# %%
# 查看是否每个 test data 的 txt 都是没换行符号
# 查看每个 test data 的 txt 中的长度
tedata_lst = glob('../data/test_data/*.txt')
for td in tedata_lst:
    if len(utils.read_txt(td))!=1:
        print(td)
len_te_lst = []
for td in tedata_lst:
    len_te_lst.append(len(utils.read_txt(td)[0]))
plt.hist(len_te_lst,bins=20)
# Out:
# ../data/test_data/1290.txt
# ../data/test_data/2673.txt
# ../data/test_data/2652.txt
# ../data/test_data/44.txt
# ../data/test_data/3932.txt
# (array([4.170e+02, 2.807e+03, 3.330e+02, 1.560e+02, 9.000e+01, 5.500e+01,
#         3.900e+01, 1.800e+01, 1.300e+01, 1.100e+01, 3.000e+00, 5.000e+00,
#         4.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 3.000e+00]),
#  array([   5.  ,   59.25,  113.5 ,  167.75,  222.  ,  276.25,  330.5 ,
#          384.75,  439.  ,  493.25,  547.5 ,  601.75,  656.  ,  710.25,
#          764.5 ,  818.75,  873.  ,  927.25,  981.5 , 1035.75, 1090.  ]),
#  <a list of 20 Patch objects>)

# %%
label_total[label_total.Category == 'movie'].head(5)
tmp1 = label_total[label_total.Category == 'movie']
def func(x):
    if x[0] in ('《','≪','（','(','＜','“','「','【') and x[-1] in ('》','≫','）',')','＞','”','」','】'):
        return True
    else:
        return False
tmp1[~tmp1.Privacy.apply(lambda x:func(x))]
# Out:
#          ID Category Pos_b Pos_e                       Privacy
# 312     828    movie    86   101              therewillbeblood
# 471     425    movie    55    68                hehuntingparty
# 472     425    movie    76    79                          猎狐行动
# 474    1199    movie    27    30                          万通苏园
# 487    1827    movie     2     6                         恰同学少年
# 488    1827    movie    54    58                         恰同学少年
# 489    1827    movie     7     9                           大马帮
# 490    1827    movie    10    13                          抗日奇侠
# 491    1827    movie    14    17                          镖行天下
# 492    1827    movie    18    21                          铁人火线
# 493    1827    movie    22    25                          追凶绝密
# 531    1166    movie   184   189                        变形金刚1》
# 598    2335    movie    40    40                             宫
# 599    2335    movie    43    46                          美人天下
# 600    2335    movie    49    51                           藏心术
# 714    2491    movie    33    44                  《愛的逃兵》張曼玉張國榮
# 799    1371    movie    29    32                          【搜神记
# 800    1371    movie    47    51                         【赤焰战场
# 820     197    movie    42    47                        冒牌天神2》
# 949     140    movie   339   342                          追梦者》
# 1144   2268    movie   188   215  thedivingbellandthebutterfly
# 1174    587    movie    41    49                     《朱诺》（juno
# 1175    587    movie    61    80          《理发师陶德》（sweeneytodd:
# 1374    591    movie     0     3                          兄弟连》
# 1402   1763    movie   249   258                    theshining
# 1470    988    movie   197   201                         欲望都市》
# 1559   1575    movie   110   111                            叶问
# 1560   1575    movie   114   116                           苏乞儿
# 1794    340    movie    32    39                      《渭水春風》屏風
# 1817    432    movie    16    20                         《皇后进宫
# ...     ...      ...   ...   ...                           ...
# 19013  1578    movie   313   316                          heat
# 19071  1020    movie    71    78                      waitress
# 19124   563    movie     1     6                        《百万新娘2
# 19129   563    movie    55    61                       毛泽东三兄弟)
# 19192   549    movie   195   198                          蜘蛛侠》
# 19202   549    movie   297   300                          碧血长空
# 19212   549    movie   476   483                      savages）
# 19213   549    movie   485   512  《潜水钟与蝴蝶》（thedivingbellandthe
# 19262   213    movie    55    59                         哈利-波特
# 19283  1787    movie   220   224                         女人不坏》
# 19513  1383    movie     5    12                      华子奇陆续上映的
# 19721  2477    movie   172   176                         厄夜三十》
# 19727  2477    movie   269   271                           仙剑五
# 19732  2477    movie   352   353                            战神
# 19773  1142    movie    47    50                          梦魇惊魂
# 19774  1142    movie    77    80                          欢喜神郎
# 20002  1355    movie     8    12                         美味的想念
# 20003  1355    movie    14    19                        武松2013
# 20004  1355    movie    21    23                           獨立連
# 20005  1355    movie    25    28                          旗袍旗袍
# 20006  1355    movie    30    33                          血色黎明
# 20007  1355    movie    35    41                       第三十六個故事
# 20008  1355    movie    43    46                          六號出口
# 20009  1355    movie    48    56                     牯嶺街少年殺人事件
# 20095   616    movie    54    66                 30DaysofNight
# 20161  1547    movie   310   317                      纳尔尼亚传奇ⅱ》
# 20209   789    movie   177   181                         杯酒人生》
# 20366  1989    movie    91    98                      刺客信条：世系》
# 20372  1989    movie   192   200                     atonement
# 20475  1792    movie    74    79                        AVATAR
#
# [420 rows x 5 columns]

# %%
label_total[label_total.Category == 'game'].head(5)
tmp2 = label_total[label_total.Category == 'game']
tmp2[~tmp2.Privacy.apply(lambda x:func(x))]
# Out:
#          ID Category Pos_b Pos_e                        Privacy
# 25      237     game     0     4                          魔兽争霸3
# 130     592     game    60    63                           WAR3
# 133     592     game    87    94                       SF“特种部队”
# 187    2094     game     5     8                           DOTA
# 231     974     game    54    57                           CSOL
# 264     141     game    12    40  《超世纪战警：突袭黑暗雅典娜》（TheChronicles
# 270      97     game    35    39                          dota2
# 272      97     game    76    79                           DotA
# 275      97     game   136   140                          星际争霸2
# 324    1370     game   167   170                           虚拟战场
# 335    2137     game    17    26                     ArxelTribe
# 358    2137     game   321   324                           DOTA
# 363    2137     game   402   405                           dota
# 364    2137     game   420   423                           imba
# 369    2137     game   487   491                          跑跑卡丁车
# 379    2137     game   621   622                             CS
# 382    2137     game   671   678                       猎魔人2国王刺客
# 399      54     game     5     8                           CSOL
# 453     800     game   134   137                           《前线：
# 458    2123     game    20    22                            星际2
# 460     431     game     2     4                            魔兽3
# 461     431     game    21    25                          魔兽争霸3
# 503    1833     game   127   130                           DOTA
# 504    1833     game   138   139                             CW
# 516     419     game   140   144                          DOTA2
# 521    1166     game     5    10                         战斗国际象棋
# 540    1166     game   371   374                           War3
# 554    2309     game   169   173                          《前线任务
# 556    2309     game   187   190                           war3
# 557    2309     game   204   207                           dota
# ...     ...      ...   ...   ...                            ...
# 19565  1368     game    94    96                            星际2
# 19606   429     game    81    84                           DotA
# 19672   367     game     4     7                           Dota
# 19673   367     game    30    33                           Dota
# 19842  1625     game    46    49                           DotA
# 19843  1625     game    64    67                           DotA
# 19892  2476     game    99   100                             星际
# 19933   366     game    97   100                           红楼梦》
# 19963  1816     game    35    37                            星际2
# 19977   428     game   141   144                           魔兽争霸
# 19990   819     game   222   223                             魔兽
# 20022  1427     game    69    76                       CSOnline
# 20023  1427     game    62    63                             CS
# 20112   616     game   323   326                           DOTA
# 20171  1235     game     0     4                          DOTA2
# 20237   945     game    89    92                           DOTA
# 20238  2066     game    29    32                           王者荣耀
# 20243  2066     game    54    57                           DOTA
# 20254   776     game    60    61                             星际
# 20266   776     game   228   236                      Dota6.72c
# 20276  2099     game    82    84                            LOL
# 20335  1751     game     1     4                           dota
# 20336  1751     game    19    22                           imba
# 20356  1751     game   261   276               《美国陆军3（America's
# 20358  1751     game   281   284                           DOTA
# 20375  1037     game     0     3                           DOTA
# 20380  1037     game    81    84                           dota
# 20382  1037     game   109   121                  Wolfenstein3D
# 20390  1037     game   261   264                           War3
# 20410  2270     game   274   275                             魔兽
#
# [904 rows x 5 columns]

# %%
label_total[label_total.Category == 'book'].head(5)
tmp3 = label_total[label_total.Category == 'game']
tmp3[~tmp2.Privacy.apply(lambda x:func(x))]
# Out:
#          ID Category Pos_b Pos_e                        Privacy
# 25      237     game     0     4                          魔兽争霸3
# 130     592     game    60    63                           WAR3
# 133     592     game    87    94                       SF“特种部队”
# 187    2094     game     5     8                           DOTA
# 231     974     game    54    57                           CSOL
# 264     141     game    12    40  《超世纪战警：突袭黑暗雅典娜》（TheChronicles
# 270      97     game    35    39                          dota2
# 272      97     game    76    79                           DotA
# 275      97     game   136   140                          星际争霸2
# 324    1370     game   167   170                           虚拟战场
# 335    2137     game    17    26                     ArxelTribe
# 358    2137     game   321   324                           DOTA
# 363    2137     game   402   405                           dota
# 364    2137     game   420   423                           imba
# 369    2137     game   487   491                          跑跑卡丁车
# 379    2137     game   621   622                             CS
# 382    2137     game   671   678                       猎魔人2国王刺客
# 399      54     game     5     8                           CSOL
# 453     800     game   134   137                           《前线：
# 458    2123     game    20    22                            星际2
# 460     431     game     2     4                            魔兽3
# 461     431     game    21    25                          魔兽争霸3
# 503    1833     game   127   130                           DOTA
# 504    1833     game   138   139                             CW
# 516     419     game   140   144                          DOTA2
# 521    1166     game     5    10                         战斗国际象棋
# 540    1166     game   371   374                           War3
# 554    2309     game   169   173                          《前线任务
# 556    2309     game   187   190                           war3
# 557    2309     game   204   207                           dota
# ...     ...      ...   ...   ...                            ...
# 19565  1368     game    94    96                            星际2
# 19606   429     game    81    84                           DotA
# 19672   367     game     4     7                           Dota
# 19673   367     game    30    33                           Dota
# 19842  1625     game    46    49                           DotA
# 19843  1625     game    64    67                           DotA
# 19892  2476     game    99   100                             星际
# 19933   366     game    97   100                           红楼梦》
# 19963  1816     game    35    37                            星际2
# 19977   428     game   141   144                           魔兽争霸
# 19990   819     game   222   223                             魔兽
# 20022  1427     game    69    76                       CSOnline
# 20023  1427     game    62    63                             CS
# 20112   616     game   323   326                           DOTA
# 20171  1235     game     0     4                          DOTA2
# 20237   945     game    89    92                           DOTA
# 20238  2066     game    29    32                           王者荣耀
# 20243  2066     game    54    57                           DOTA
# 20254   776     game    60    61                             星际
# 20266   776     game   228   236                      Dota6.72c
# 20276  2099     game    82    84                            LOL
# 20335  1751     game     1     4                           dota
# 20336  1751     game    19    22                           imba
# 20356  1751     game   261   276               《美国陆军3（America's
# 20358  1751     game   281   284                           DOTA
# 20375  1037     game     0     3                           DOTA
# 20380  1037     game    81    84                           dota
# 20382  1037     game   109   121                  Wolfenstein3D
# 20390  1037     game   261   264                           War3
# 20410  2270     game   274   275                             魔兽
#
# [904 rows x 5 columns]

# %%
# 查看每个 train data 的 txt 中的标点符号
import re
filter_p = re.compile(r'[^\u4e00-\u9fa50-9A-Za-z]')
symbol_lst = []
for td in tdata_lst:
    symbol_lst += re.findall(filter_p,utils.read_txt(td)[0])
symbol_lst = np.unique(symbol_lst)

# %%
symbol_lst
# Out:
# array(['\t', '!', '"', '#', '%', '&', "'", '(', ')', '*', '+', '-', '.',
#        '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_',
#        '`', '{', '|', '}', '~', '«', '·', '»', '×', 'ω', 'ค', 'ช', 'ต',
#        'ะ', 'า', 'โ', '\u2006', '—', '‘', '’', '“', '”', '•', '…',
#        '\u2029', '\u202a', '\u202c', '※', 'Ⅱ', 'Ⅲ', 'Ⅳ', 'Ⅶ', 'ⅰ', 'ⅱ',
#        'ⅲ', 'ⅳ', 'ⅵ', '↑', '→', '↓', '∩', '∶', '≪', '≫', '⊙', '⋯', '①',
#        '②', '─', '┃', '■', '□', '◆', '●', '★', '☆', '☏', '♪', '\u3000',
#        '、', '。', '〃', '〈', '〉', '《', '》', '「', '」', '『', '』', '【', '】',
#        '〜', 'あ', 'い', 'え', 'が', 'き', 'く', 'こ', 'し', 'す', 'た', 'ち', 'っ',
#        'つ', 'て', 'で', 'と', 'な', 'に', 'の', 'は', 'ま', 'み', 'や', 'ら', 'る',
#        'れ', 'を', 'ん', 'コ', 'ス', 'タ', 'ト', 'ニ', '・', 'ー', '䢖', '녕', '세',
#        '안', '요', '하', '\ue056', '\ue253', '\ue316', '\ue404', '\ue41d',
#        '\ue449', '\uf87d', '﹐', '﹔', '﹕', '﹗', '﹣', '！', '＂', '＄', '＆',
#        '（', '）', '＋', '，', '－', '．', '／', '０', '６', '：', '；', '＜', '＞',
#        '？', '＠', 'Ｔ', '［', '＼', '］', 'ｃ', 'ｅ', 'ｌ', 'ｍ', 'ｓ', '｜', '～',
#        '｟', '｠', '｢', '｣'], dtype='<U1')

# %%
for s in ('.','。','!','！','?','？','⋯','…','﹗'):
    if s not in symbol_lst:
        print(s)

# %%
# 查看标签中是否有标点符号
import re
filter_p = re.compile(r'[^\u4e00-\u9fa50-9A-Za-z]')
symbol_lst = []
for label in label_total.Privacy:
    symbol_lst += re.findall(filter_p,str(label))
symbol_lst = np.unique(symbol_lst)

# %%
for s in ('.','。','!','！','?','？','⋯','…','﹗'):
    if s not in symbol_lst:
        print(s)
# Out:
# ？
# ⋯
# …
# ﹗
